# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in ./env/lib/python3.8/site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in ./env/lib/python3.8/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in ./env/lib/python3.8/site-packages (from yfinance) (1.23.2)
# Requirement already satisfied: requests>=2.31 in ./env/lib/python3.8/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in ./env/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in ./env/lib/python3.8/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in ./env/lib/python3.8/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in ./env/lib/python3.8/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in ./env/lib/python3.8/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in ./env/lib/python3.8/site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./env/lib/python3.8/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./env/lib/python3.8/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in ./env/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in ./env/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in ./env/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.9.0)
# Requirement already satisfied: tzdata>=2022.1 in ./env/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
rel = yf.Ticker("RELIANCE.NS")

# %%
rel = rel.history(period="max")

# %%
rel
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1996-01-01 00:00:00+05:30     3.988640     4.010042     3.962373     4.003232
# 1996-01-02 00:00:00+05:30     3.993503     4.012960     3.942915     3.972100
# 1996-01-03 00:00:00+05:30     4.037280     4.221147     3.993503     4.002258
# 1996-01-04 00:00:00+05:30     3.964318     3.976964     3.911784     3.965290
# 1996-01-05 00:00:00+05:30     3.949724     3.949724     3.904001     3.938050
# ...                                ...          ...          ...          ...
# 2024-12-18 00:00:00+05:30  1240.650024  1259.949951  1240.650024  1253.250000
# 2024-12-19 00:00:00+05:30  1239.000000  1244.900024  1229.000000  1230.449951
# 2024-12-20 00:00:00+05:30  1224.000000  1239.500000  1201.500000  1205.300049
# 2024-12-23 00:00:00+05:30  1215.000000  1227.199951  1213.199951  1222.300049
# 2024-12-24 00:00:00+05:30  1222.300049  1233.550049  1221.000000  1222.750000
#
#                               Volume  Dividends  Stock Splits
# Date
# 1996-01-01 00:00:00+05:30  104121369        0.0           0.0
# 1996-01-02 00:00:00+05:30  168743308        0.0           0.0
# 1996-01-03 00:00:00+05:30  209323879        0.0           0.0
# 1996-01-04 00:00:00+05:30  216900264        0.0           0.0
# 1996-01-05 00:00:00+05:30  166708467        0.0           0.0
# ...                              ...        ...           ...
# 2024-12-18 00:00:00+05:30   12670179        0.0           0.0
# 2024-12-19 00:00:00+05:30   14244653        0.0           0.0
# 2024-12-20 00:00:00+05:30   20312896        0.0           0.0
# 2024-12-23 00:00:00+05:30   10052824        0.0           0.0
# 2024-12-24 00:00:00+05:30    6734917        0.0           0.0
#
# [7277 rows x 7 columns]

# %%
rel.index
# Out:
# DatetimeIndex(['1996-01-01 00:00:00+05:30', '1996-01-02 00:00:00+05:30',
#                '1996-01-03 00:00:00+05:30', '1996-01-04 00:00:00+05:30',
#                '1996-01-05 00:00:00+05:30', '1996-01-08 00:00:00+05:30',
#                '1996-01-09 00:00:00+05:30', '1996-01-10 00:00:00+05:30',
#                '1996-01-11 00:00:00+05:30', '1996-01-12 00:00:00+05:30',
#                ...
#                '2024-12-11 00:00:00+05:30', '2024-12-12 00:00:00+05:30',
#                '2024-12-13 00:00:00+05:30', '2024-12-16 00:00:00+05:30',
#                '2024-12-17 00:00:00+05:30', '2024-12-18 00:00:00+05:30',
#                '2024-12-19 00:00:00+05:30', '2024-12-20 00:00:00+05:30',
#                '2024-12-23 00:00:00+05:30', '2024-12-24 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=7277, freq=None)

# %%
 rel.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
if "Dividends" in rel:  
    del rel["Dividends"]

# %%
if "Stock Splits" in rel: 
    del rel["Stock Splits"]

# %%
rel["Tomorrow"] = rel["Close"].shift(-1)

# %%
rel
# Out:
#                                   Open         High          Low        Close  \
# Date
# 
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-01-04 00:00:00+05:30   211.926136   211.926136   198.475603   208.896118
# 2010-01-05 00:00:00+05:30   223.346967   223.346967   206.934382   207.963806
# 2010-01-06 00:00:00+05:30   209.750722   212.586514   207.954079   211.324005
# 2010-01-07 00:00:00+05:30   211.323993   216.568240   209.381668   214.829865
# 2010-01-08 00:00:00+05:30   215.208655   216.335205   212.877877   214.266632
# ...                                ...          ...          ...          ...
# 2024-12-18 00:00:00+05:30  1240.650024  1259.949951  1240.650024  1253.250000
# 2024-12-19 00:00:00+05:30  1239.000000  1244.900024  1229.000000  1230.449951
# 2024-12-20 00:00:00+05:30  1224.000000  1239.500000  1201.500000  1205.300049
# 2024-12-23 00:00:00+05:30  1215.000000  1227.199951  1213.199951  1222.300049
# 2024-12-24 00:00:00+05:30  1222.300049  1233.550049  1221.000000  1222.750000
#
#                              Volume     Tomorrow  Target
# Date
# 2010-01-04 00:00:00+05:30  76646086   207.963806       0
# 2010-01-05 00:00:00+05:30  21392825   211.324005       1
# 2010-01-06 00:00:00+05:30  23691760   214.829865       1
# 2010-01-07 00:00:00+05:30  26197920   214.266632       0
# 2010-01-08 00:00:00+05:30  15110149   210.061508       0
# ...                             ...          ...     ...
# 2024-12-18 00:00:00+05:30  12670179  1230.449951       0
# 2024-12-19 00:00:00+05:30  14244653  1205.300049       0
# 2024-12-20 00:00:00+05:30  20312896  1222.300049       1
# 2024-12-23 00:00:00+05:30  10052824  1222.750000       1
# 2024-12-24 00:00:00+05:30   6734917          NaN       0
#
# [3696 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = rel.iloc[:-100]
test = rel.iloc[-100:]

predictors = ["Close", "Open", "Volume", "High", "Low"] 
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.46551724137931033

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, mdoel):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index= test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):  #250 days is one year for a stock so we are taking 10 yrs of data to backtest
    all_predictions = [] 

    for i in range(start, data.shape[0], step): 
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy() 
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(rel, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    775
# 1    421
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5391923990498813

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.522575
# 0    0.477425
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = [] 

for horizon in horizons: 
    rolling_averages = rel.rolling(horizon).mean() 

    ratio_column = f"Close_Ratio_{horizon}" 
    rel[ratio_column] = rel["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}" 
    rel[trend_column] = rel.shift(1).rolling(horizon).sum()["Target"] 

    new_predictors  += [ratio_column, trend_column]

# %%
rel
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-01-04 00:00:00+05:30   211.926136   211.926136   198.475603   208.896118
# 2010-01-05 00:00:00+05:30   223.346967   223.346967   206.934382   207.963806
# 2010-01-06 00:00:00+05:30   209.750722   212.586514   207.954079   211.324005
# 2010-01-07 00:00:00+05:30   211.323993   216.568240   209.381668   214.829865
# 2010-01-08 00:00:00+05:30   215.208655   216.335205   212.877877   214.266632
# ...                                ...          ...          ...          ...
# 2024-12-18 00:00:00+05:30  1240.650024  1259.949951  1240.650024  1253.250000
# 2024-12-19 00:00:00+05:30  1239.000000  1244.900024  1229.000000  1230.449951
# 2024-12-20 00:00:00+05:30  1224.000000  1239.500000  1201.500000  1205.300049
# 2024-12-23 00:00:00+05:30  1215.000000  1227.199951  1213.199951  1222.300049
# 2024-12-24 00:00:00+05:30  1222.300049  1233.550049  1221.000000  1222.750000
#
#                              Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 2010-01-04 00:00:00+05:30  76646086   207.963806       0            NaN
# 2010-01-05 00:00:00+05:30  21392825   211.324005       1       0.997763
# 2010-01-06 00:00:00+05:30  23691760   214.829865       1       1.008014
# 2010-01-07 00:00:00+05:30  26197920   214.266632       0       1.008227
# 2010-01-08 00:00:00+05:30  15110149   210.061508       0       0.998687
# ...                             ...          ...     ...            ...
# 2024-12-18 00:00:00+05:30  12670179  1230.449951       0       1.003182
# 2024-12-19 00:00:00+05:30  14244653  1205.300049       0       0.990820
# 2024-12-20 00:00:00+05:30  20312896  1222.300049       1       0.989675
# 2024-12-23 00:00:00+05:30  10052824  1222.750000       1       1.007003
# 2024-12-24 00:00:00+05:30   6734917          NaN       0       1.000184
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2010-01-04 00:00:00+05:30      NaN            NaN      NaN             NaN
# 2010-01-05 00:00:00+05:30      NaN            NaN      NaN             NaN
# 2010-01-06 00:00:00+05:30      1.0            NaN      NaN             NaN
# 2010-01-07 00:00:00+05:30      2.0            NaN      NaN             NaN
# 2010-01-08 00:00:00+05:30      1.0       1.013291      NaN             NaN
# ...                            ...            ...      ...             ...
# 2024-12-18 00:00:00+05:30      1.0       0.994233      2.0        0.939117
# 2024-12-19 00:00:00+05:30      1.0       0.981197      2.0        0.925070
# 2024-12-20 00:00:00+05:30      0.0       0.971609      1.0        0.909399
# 2024-12-23 00:00:00+05:30      1.0       0.992675      2.0        0.925386
# 2024-12-24 00:00:00+05:30      2.0       0.996691      3.0        0.928953
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2010-01-04 00:00:00+05:30       NaN              NaN        NaN
# 2010-01-05 00:00:00+05:30       NaN              NaN        NaN
# 2010-01-06 00:00:00+05:30       NaN              NaN        NaN
# 2010-01-07 00:00:00+05:30       NaN              NaN        NaN
# 2010-01-08 00:00:00+05:30       NaN              NaN        NaN
# ...                             ...              ...        ...
# 2024-12-18 00:00:00+05:30      29.0         0.883112      132.0
# 2024-12-19 00:00:00+05:30      28.0         0.867003      131.0
# 2024-12-20 00:00:00+05:30      28.0         0.849336      130.0
# 2024-12-23 00:00:00+05:30      28.0         0.861367      130.0
# 2024-12-24 00:00:00+05:30      28.0         0.861765      130.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2010-01-04 00:00:00+05:30               NaN         NaN
# 2010-01-05 00:00:00+05:30               NaN         NaN
# 2010-01-06 00:00:00+05:30               NaN         NaN
# 2010-01-07 00:00:00+05:30               NaN         NaN
# 2010-01-08 00:00:00+05:30               NaN         NaN
# ...                                     ...         ...
# 2024-12-18 00:00:00+05:30          1.063816       523.0
# 2024-12-19 00:00:00+05:30          1.044162       522.0
# 2024-12-20 00:00:00+05:30          1.022550       521.0
# 2024-12-23 00:00:00+05:30          1.036677       522.0
# 2024-12-24 00:00:00+05:30          1.036767       522.0
#
# [3696 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, mdoel):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1  
    preds[preds <  .6] = 0 
    preds = pd.Series(preds, index= test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(rel, model, new_predictors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 predictions = backtest(rel, model, new_predictors)
#
# Cell In[46], line 7, in backtest(data, model, predictors, start, step)
#       5     train = data.iloc[0:i].copy()
#       6     test = data.iloc[i:(i+step)].copy()
# ----> 7     predictions = predict(train, test, predictors, model)
#       8     all_predictions.append(predictions)
#       9 return pd.concat(all_predictions)
#
# Cell In[55], line 2, in predict(train, test, predictors, mdoel)
#       1 def predict(train, test, predictors, mdoel):
# ----> 2     model.fit(train[predictors], train["Target"])
#       3     preds = model.predict_proba(test[predictors])[:,1]
#       4     preds[preds >= .6] = 1
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/utils/validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/utils/validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/utils/validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     119 if first_pass_isfinite:
#     120     return
# --> 122 _assert_all_finite_element_wise(
#     123     X,
#     124     xp=xp,
#     125     allow_nan=allow_nan,
#     126     msg_dtype=msg_dtype,
#     127     estimator_name=estimator_name,
#     128     input_name=input_name,
#     129 )
#
# File ~/Documents/mlEnv/env/lib/python3.8/site-packages/sklearn/utils/validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     154 if estimator_name and input_name == "X" and has_nan_error:
#     155     # Improve the error message on how to handle missing values in
#     156     # scikit-learn.
#     157     msg_err += (
#     158         f"\n{estimator_name} does not accept missing values"
#     159         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     169         "#estimators-that-handle-nan-values"
#     170     )
# --> 171 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    1092
# 1.0     104
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5096153846153846
